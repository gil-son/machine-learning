# %%
import pandas as pd

table = pd.read_csv("clients.csv") # Import the database.
display(table)
# Out:
#      id_cliente  mes  idade  profissao  salario_anual  num_contas  \
# 0          3392    1     23  cientista       19114.12           3
# 1          3392    2     23  cientista       19114.12           3
# 2          3392    3     23  cientista       19114.12           3
# 3          3392    4     23  cientista       19114.12           3
# 4          3392    5     23  cientista       19114.12           3
# ..          ...  ...    ...        ...            ...         ...
# 995       43430    4     27     musico       63536.98           4
# 996       43430    5     27     musico       63536.98           4
# 997       43430    6     27     musico       63536.98           4
# 998       43430    7     27     musico       63536.98           4
# 999       43430    8     27     musico       63536.98           4
#
#      num_cartoes  juros_emprestimo  num_emprestimos  dias_atraso  ...  \
# 0              4                 3                4            3  ...
# ...

# %%
# check if we have empty values or values recognized in the wrong format
print(table.info())
print(table.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_cliente                1000 non-null   int64
#  1   mes                       1000 non-null   int64
#  2   idade                     1000 non-null   int64
#  3   profissao                 1000 non-null   object
#  4   salario_anual             1000 non-null   float64
#  5   num_contas                1000 non-null   int64
#  6   num_cartoes               1000 non-null   int64
#  7   juros_emprestimo          1000 non-null   int64
#  8   num_emprestimos           1000 non-null   int64
#  9   dias_atraso               1000 non-null   int64
#  10  num_pagamentos_atrasados  1000 non-null   int64
#  11  num_verificacoes_credito  1000 non-null   int64
#  12  mix_credito               1000 non-null   object
#  13  divida_total              1000 non-null   float64
# ...

# %% [markdown]
# # AI Project: Artificial Intelligence and Predictions
#
# ### Case: Score de Crédito dos Clientes
#
# Case: Customer Credit Scores
#
# You have been hired by a bank to determine the credit scores of its customers. Your task is to analyze all the bank's customers and, based on this analysis, create a model that can automatically assess customer information and assign a credit score: Poor, Okay, Good.
#
# files: https://drive.google.com/drive/folders/1FbDqVq4XLvU85VBlVIMJ73p9oOu6u2-J?usp=drive_link

# %%
from sklearn.preprocessing import LabelEncoder
# it will transform the text columns into numbers, for example: professions will change from scientist, teacher, mechanic, etc., to 0, 1, 2, etc.

# we just won't apply it to the credit score column, which is our target variable
for column in table.columns:
    if table[column].dtype == "object" and column != "score_credito":
        table[column] = encoder.fit_transform(table[column])

# checking to ensure that indeed all columns have been modified.
print(table.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_cliente                1000 non-null   int64
#  1   mes                       1000 non-null   int64
#  2   idade                     1000 non-null   int64
#  3   profissao                 1000 non-null   int64
#  4   salario_anual             1000 non-null   float64
#  5   num_contas                1000 non-null   int64
#  6   num_cartoes               1000 non-null   int64
#  7   juros_emprestimo          1000 non-null   int64
#  8   num_emprestimos           1000 non-null   int64
#  9   dias_atraso               1000 non-null   int64
#  10  num_pagamentos_atrasados  1000 non-null   int64
#  11  num_verificacoes_credito  1000 non-null   int64
#  12  mix_credito               1000 non-null   int64
#  13  divida_total              1000 non-null   float64
# ...

# %%
# choosing which columns we will use to train the model
# y is the column we want the model to predict
# x includes all the columns we will use to predict the credit score; we won't use the client_id column because it is just a random number that doesn't contribute to the prediction
x = table.drop(["score_credito", "id_cliente"], axis=1)
y = table["score_credito"]

from sklearn.model_selection import train_test_split

# we've split the data into training and testing sets. The training set is given to the models for learning, and the testing set is used to check if the model has learned correctly
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

modelo_arvore = RandomForestClassifier()  # Decision tree model
modelo_knn = KNeighborsClassifier()  # KNN model (k-nearest neighbors)

# Training the models
modelo_arvore.fit(x_train, y_train)
modelo_knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# if our model guessed "Standard" for everything, what would be the accuracy of the model?
score_counts = table["score_credito"].value_counts()
print(score_counts['Standard'] / sum(score_counts))
# Out:
# 0.527

# %%
from sklearn.metrics import accuracy_score

# calculate predictions
prediction_tree = modelo_arvore.predict(x_test)
prediction_knn = modelo_knn.predict(x_test.to_numpy())

# compare predictions with y_teste
# we want this score to be higher (higher accuracy), but it also needs to be higher than the "Standard" guess
print(accuracy_score(y_test, prediction_tree))
print(accuracy_score(y_test, prediction_knn))
# Out:
# 0.8133333333333334
# 0.8166666666666667
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
# fazendo novas previsões
new_clients = pd.read_csv("new_clients.csv")
display(new_clients)
for column in new_clients.columns:
    if new_clients[column].dtype == "object" and column != "score_credito":
        new_clients[column] = codificador.fit_transform(new_clients[column])

predictions = modelo_arvore.predict(new_clients)
print(predictions)
# Out:
#    mes  idade   profissao  salario_anual  num_contas  num_cartoes  \
# 0    1   31.0  empresario      19300.340         6.0          7.0
# 1    4   32.0    advogado      12600.445         5.0          5.0
# 2    2   48.0  empresario      20787.690         8.0          6.0
#
#    juros_emprestimo  num_emprestimos  dias_atraso  num_pagamentos_atrasados  \
# 0              17.0              5.0         52.0                      19.0
# 1              10.0              3.0         25.0                      18.0
# 2              14.0              7.0         24.0                      14.0
#
#    ...  taxa_uso_credito idade_historico_credito  investimento_mensal  \
# 0  ...         29.934186                   218.0             44.50951
# 1  ...         28.819407                    12.0              0.00000
# 2  ...         34.235853                   215.0              0.00000
#
#        comportamento_pagamento  saldo_final_mes  emprestimo_carro  \
# ...

# %%
# what are the most important features to determine the credit score?
columns = list(x_test.columns)
importance = pd.DataFrame(index=columns, data=modelo_arvore.feature_importances_)
importance = importance * 100
print(importance)
# Out:
#                                  0
# mes                       5.181282
# idade                     4.484837
# profissao                 3.553808
# salario_anual             5.686203
# num_contas                4.578913
# num_cartoes               3.309671
# juros_emprestimo          6.195433
# num_emprestimos           2.324393
# dias_atraso               6.816630
# num_pagamentos_atrasados  6.206955
# num_verificacoes_credito  4.221722
# mix_credito               7.197082
# divida_total              7.176261
# taxa_uso_credito          5.794914
# idade_historico_credito   9.257621
# investimento_mensal       4.645229
# comportamento_pagamento   3.191368
# saldo_final_mes           6.761426
# emprestimo_carro          0.742324
# emprestimo_casa           0.597544
# emprestimo_pessoal        0.639935
# emprestimo_credito        0.543020
# emprestimo_estudantil     0.893431
